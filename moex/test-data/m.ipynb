# %%
import polars as pl

# %%
pl.read_csv("./5000.txt",dtypes={"PRICE": str})
# Out:
# shape: (4999, 10)
# ┌─────────────┬────────┬──────┬───────────────────┬─────┬──────────┬────────┬─────────┬────────────┐
# │ #SYMBOL     ┆ SYSTEM ┆ TYPE ┆ MOMENT            ┆ ... ┆ PRICE    ┆ VOLUME ┆ ID_DEAL ┆ PRICE_DEAL │
# │ ---         ┆ ---    ┆ ---  ┆ ---               ┆     ┆ ---      ┆ ---    ┆ ---     ┆ ---        │
# │ str         ┆ str    ┆ str  ┆ i64               ┆     ┆ str      ┆ i64    ┆ str     ┆ str        │
# ╞═════════════╪════════╪══════╪═══════════════════╪═════╪══════════╪════════╪═════════╪════════════╡
# │ Si73750BC2  ┆ C      ┆ B    ┆ 20220131185256610 ┆ ... ┆ 1.00000  ┆ 1      ┆ null    ┆ null       │
# │ Si74250BO2  ┆ P      ┆ B    ┆ 20220131185256620 ┆ ... ┆ 1.00000  ┆ 1      ┆ null    ┆ null       │
# │ Si73750BO2  ┆ P      ┆ B    ┆ 20220131185256627 ┆ ... ┆ 1.00000  ┆ 1      ┆ null    ┆ null       │
# │ Si74750BO2  ┆ P      ┆ B    ┆ 20220131185256627 ┆ ... ┆ 1.00000  ┆ 1      ┆ null    ┆ null       │
# ...

# %%
pl.read_csv("./5000.txt").groupby("PRICE_DEAL").count()
# Out:
# shape: (14, 2)
# ┌────────────┬───────┐
# │ PRICE_DEAL ┆ count │
# │ ---        ┆ ---   │
# │ str        ┆ u32   │
# ╞════════════╪═══════╡
# │ 2.58000    ┆ 2     │
# │ 1.92000    ┆ 2     │
# │ 3.94000    ┆ 2     │
# │ 3.80000    ┆ 2     │
# │ ...        ┆ ...   │
# │ null       ┆ 4971  │
# │ 0.78000    ┆ 2     │
# │ 5.57000    ┆ 2     │
# │ 0.44000    ┆ 4     │
# └────────────┴───────┘
